# %% [markdown]
# In this task, you are to scrape the latest, trending financial news headlines. (The news can start from the present day to 1 year before)
#
# the websites you can use are:
#
# https://www.nseindia.com/
#
# https://www.moneycontrol.com/
#
# https://economictimes.indiatimes.com/markets
#
# https://stockanalysis.com/news/all-stocks/
#
# https://seekingalpha.com/market-news
#
# your code must return a csv file containing the date when the headline was posted, the headline itself and any other relevant column.

# %%
#import necessary libraries here
# !pip install bs4
import requests
from bs4 import BeautifulSoup

# %%
#logic here

url = "https://www.financialexpress.com/money/"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
           "Accept-Language": "en-GB,en;q=0.9,hi-IN;q=0.8,hi;q=0.7,te-IN;q=0.6,te;q=0.5,en-US;q=0.4"}

r = requests.get(url,headers = headers)
soup = BeautifulSoup(r.text,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="wf-montserrat-n4-active wf-montserrat-n6-active wf-montserrat-n5-active wf-active" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://www.financialexpress.com/money/page/2/" rel="next"/>
#   <script id="rtpwa" type="text/worker">
#    onmessage=function(e){var o=new Request(e.data,{mode:"no-cors",redirect:"follow"});fetch(o)};
#   </script>
#   <script>
#    var x = new Worker("data:text/javascript;base64," + btoa(document.getElementById("rtpwa").textContent));
#   </script>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="NOODP" name="robots"/>
#   <meta content="max-image-preview:large" name="robots"/>
#   <meta content="money, business news, banking news, finance news, money management, latest finance news, money news, investment news, personal finance news,income tax, personal finance, mutual funds, investing, saving news,money management" name="keywords"/>
# ...

# %%
s = soup.find_all(class_ = "entry-title")
for article in s:
  print(article.string)
# Out:
# Expect Tier 2 cities to gain more momentum as prime residential markets soon: Sudhir Pai, Magicbricks
# Filing belated ITR for FY 2022-23 (AY 2023-24): Know all about ITR Form 1, 2 and other key eligibility criteria
# How do deepfakes impact banks and other financial institutions?
# How PropTech is transforming real estate in India
# Mumbai, Pune & Hyderabad to significantly shape real estate’s narrative in upcoming months: Housing.com
# 7 lessons to learn from this year’s investment mistakes
# Top 5 investment themes that may shape the stock market in 2024
# Prize-Linked Savings: A new way of saving while winning exciting rewards
# Your Money: Rate cuts coming, but how soon?
# Strategy to balance high valuations in Mid & small caps: Go for multi-cap funds to reduce risks
# 9 crucial situations when gold loan can come to your rescue
# Jеwar Airport poisеd to bе a catalyst for the growth of Faridabad’s real estate: Aman Gupta, RPS Group
# ...
